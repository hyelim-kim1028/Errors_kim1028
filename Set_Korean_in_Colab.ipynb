# %%
# import libraries 
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc 
import numpy as np

# %%
# !apt-get -qq -y install fonts-nanum > /dev/null

# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
# solution: changed from !apt to !apt-get

# %%
# METHOD1 
# First trial -> DID NOT WORK 
# solution: rerun the runtime code
#set Korean 
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)

fm._rebuild()

# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# Colab 의 한글 폰트 설정
plt.rc('font', family='NanumGothic')

# %%
plt.text(0.3, 0.3, '한글', size = 100)
# Out:
# Text(0.3, 0.3, '한글')

# %%
plt.plot(range(50), range(50),'r')
plt.title('제발', fontproperties = font)
plt.ylabel('되라',fontproperties = font)
plt.xlabel('한글한글',fontproperties = font)
plt.show()

# %%
# METHOD2 -> DID NOT WORK 
font_name = fm.FontProperties(fname="/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf").get_name() # 시각화시 한글 설정
rc('font', family=font_name)

# %%
# check KOR font setting I 
def current_font():
  print(f"설정 폰트 글꼴: {plt.rcParams['font.family']}, 설정 폰트 사이즈: {plt.rcParams['font.size']}")  # 파이썬 3.6 이상 사용가능하다
        
current_font()
# Out:
# 설정 폰트 글꼴: ['NanumBarunGothic'], 설정 폰트 사이즈: 10.0

# %%
# METHOD3 works 
# REFERENCE: https://buomsoo-kim.github.io/colab/2018/04/27/Using-External-fonts-in-colab.md/

# %%
#check KOR font setting II
mpl.font_manager._rebuild()
# plt.text(0.3,0.3,'한글',size=100)

plt.plot(range(50), range(50),'r')
plt.title('제발')
plt.ylabel('되라')
plt.xlabel('한글한글')
plt.show()

# %% [markdown]
# FONT INSTALLATION

# %%
# Google Noto Fonts 
# https://www.google.co.kr/get/noto/ #Noto Sans CJK KR
# name of the font file: NotoSansCJKkr-Medium.otf 
# download link: https://noto-website-2.storage.googleapis.com/pkgs/NotoSansCJKkr-hinted.zip #다운로드 버튼에서 링크복사 

# Disclaimer: 해당 사이트에서 실제로(?) 다운받을 필요는 없다. 여기서 하면됨 

# Ubuntu Terminal Code 
# download the zip file #!wget "source_of_your_target_file = link"
# !wget "https://noto-website-2.storage.googleapis.com/pkgs/NotoSansCJKkr-hinted.zip"

# %%
#unzip font file #다운로드받은 파일압축을 푼다 
# !unzip "your_file_name"

# !unzip NotoSansCJKkr-hinted.zip

# %%
# Move font files 
# !mv "your font file name" "font directory"
# font file name from unzipped file 
# font directory 

# !mv NotoSansCJKkr-Medium.otf /usr/share/fonts/truetype/

# %% [markdown]
# TEST

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm 


# fetch the name of font that was installed 
# path = '/usr/share/fonts/truetype/your_font_name'
# fontprop = fm.FontProperties(fname=path)

path = '/usr/share/fonts/truetype/NotoSansCJKkr-Medium.otf'
fontprop = fm.FontProperties(fname=path, size = 15)

plt.plot(range(50), range(50),'r')
plt.title('제발', fontproperties = fontprop)
plt.ylabel('되라',fontproperties = fontprop)
plt.xlabel('한글한글',fontproperties = fontprop)
plt.show()

# %%
def current_font():
  print(f"설정 폰트 글꼴: {plt.rcParams['font.family']}, 설정 폰트 사이즈: {plt.rcParams['font.size']}")  # 파이썬 3.6 이상 사용가능하다
        
current_font()
# Out:
# 설정 폰트 글꼴: ['Noto Sans CJK KR'], 설정 폰트 사이즈: 10.0

# %%
plt.rc('font',family='Noto Sans CJK KR')
plt.rc('axes', unicode_minus=False)

plt.text(0.3, 0.3, '한글', size = 100)
# Out:
# Text(0.3, 0.3, '한글')
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0, flags=flags)
